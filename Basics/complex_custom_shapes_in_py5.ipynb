# %%
size(800, 800)
grid = load_image('grid.png') # load image
image(grid, 0, 0) # display image (image, xco, yco)
no_fill()
stroke_weight(3)

stroke('#0099FF') # pale blue
# line(100,100, 400,400)
curve(0,0, 100,100, 400,400, 500,500)

stroke('#FFFF00') # yellow
curve(0,250, 100,100, 400,400, 500,250) # first two and last two numbers are control points

stroke('#FF9900') # orange
# control point 1:
curve(0,250, 0,250, 100,100, 400,400)
# control point 2:
curve(100,100, 400,400, 500,250, 500,250)

stroke('#11CC88') # mint green
# ellipses at the control points for our yellow curve
ellipse(0, 250, 20, 20)
ellipse(500, 250, 20, 20)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
size(800, 800)
grid = load_image("grid.png") 
image(grid, 0, 0, width / 2, height / 2) 
image(grid, width / 2, 0, width / 2, height / 2)
image(grid, 0, height / 2, width / 2, height / 2)
image(grid, width / 2, height / 2, width / 2, height / 2)
no_fill()
stroke_weight(3)

# first quadrant
curve_tightness(-5) # affects elsticity of curves
stroke("#0099ff") # pale blue
curve(0, 0, 50, 50, 200, 200, 250, 250)

stroke("#ffff00") # yellow
curve(0, 125, 50, 50, 200, 200, 250, 125)

stroke("#ff9900") # orange
curve(0, 125, 0, 125, 50, 50, 200, 200)
curve(50, 50, 200, 200, 250, 125, 250, 125)

stroke("#11cc88") # mint green
ellipse(0, 125, 10, 10)
ellipse(250, 125, 10, 10)

# second quadrant
curve_tightness(-1)
stroke("#0099ff") # pale blue
curve(400, 0, 450, 50, 600, 200, 650, 250)

stroke("#ffff00") # yellow
curve(400, 125, 450, 50, 600, 200, 650, 125)

stroke("#ff9900") # orange
curve(400, 125, 400, 125, 450, 50, 600, 200)
curve(450, 50, 600, 200, 650, 125, 650, 125)

stroke("#11cc88") # mint green
ellipse(400, 125, 10, 10)
ellipse(650, 125, 10, 10)

# third quadrant
curve_tightness(1)
stroke("#0099ff") # pale blue
curve(0, 400, 50, 450, 200, 600, 250, 650)

stroke("#ffff00") # yellow
curve(0, 525, 50, 450, 200, 600, 250, 525)

stroke("#ff9900") # orange
curve(0, 525, 0, 525, 50, 450, 200, 600)
curve(50, 450, 200, 600, 250, 525, 250, 525)

stroke("#11cc88") # mint green
ellipse(0, 525, 10, 10)
ellipse(250, 525, 10, 10)

# fourth quadrant
curve_tightness(5)
stroke("#0099ff") # pale blue
curve(400, 400, 450, 450, 600, 600, 650, 650)

stroke("#ffff00") # yellow
curve(400, 525, 450, 450, 600, 600, 650, 525)

stroke("#ff9900") # orange
curve(400, 525, 400, 525, 450, 450, 600, 600)
curve(450, 450, 600, 600, 650, 525, 650, 525)

stroke("#11cc88") # mint green
ellipse(400, 525, 10, 10)
ellipse(650, 525, 10, 10)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
size(800, 800)
grid = load_image("grid.png")
image(grid, 0, 0)
no_fill()
stroke_weight(3)

"""
bezier(vertex_point_1_x, vertex_point_1_y,
       control_point_1_x, control_point_1_y,
       control_point_2_x, control_point_2_y,
       vertex_point_2_x, vertex_point_2_y)
"""

stroke("#ff99ff") # pink
cp1x = 150
cp1y = 100
cp2x = 450
cp2y = 450
bezier(400, 100, cp1x, cp1y, cp2x, cp2y, 100, 400)

stroke("#11cc88") # mint green
ellipse(cp1x, cp1y, 20, 20)
ellipse(cp2x, cp2y, 20, 20)

stroke("#ff0000") # red
line(400, 100, cp1x, cp1y)
stroke("#ff0000") # red
line(100, 400, cp2x, cp2y)
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>

# %%
size(800, 800)
grid = load_image("grid.png")
image(grid, 0, 0)
no_fill()
stroke("#fff")
stroke_weight(3)

begin_shape()
vertex(100, 100)
vertex(200, 100)
vertex(200, 200)
vertex(100, 200)
end_shape(CLOSE)

fill("#6633ff")
begin_shape()
vertex(300, 100)
vertex(400, 100)
vertex(400, 200)
vertex(300, 200)
end_shape()

no_fill()
stroke_weight(6)
begin_shape(POINTS)
vertex(200, 300)
vertex(300, 300)
vertex(300, 400)
vertex(200, 400)
end_shape()

stroke_weight(3)
begin_shape(LINES)
vertex(400, 300)
vertex(500, 300)
vertex(500, 400)
vertex(400, 400)
end_shape()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800>
